# %%
import pandas as pd

# %% [markdown]
# # Parsing raw html strings

# %%
html_string = """
<table>
    <thead>
      <tr>
        <th>Order date</th>
        <th>Region</th> 
        <th>Item</th>
        <th>Units</th>
        <th>Unit cost</th>
      </tr>
    </thead>
    <tbody>
      <tr>
        <td>1/6/2018</td>
        <td>East</td> 
        <td>Pencil</td>
        <td>95</td>
        <td>1.99</td>
      </tr>
      <tr>
        <td>1/23/2018</td>
        <td>Central</td> 
        <td>Binder</td>
        <td>50</td>
        <td>19.99</td>
      </tr>
      <tr>
        <td>2/9/2018</td>
        <td>Central</td> 
        <td>Pencil</td>
        <td>36</td>
        <td>4.99</td>
      </tr>
      <tr>
        <td>3/15/2018</td>
        <td>West</td> 
        <td>Pen</td>
        <td>27</td>
        <td>19.99</td>
      </tr>
    </tbody>
</table>
"""

# %%
from IPython.core.display import display, HTML
display(HTML(html_string))
# Out:
# <table>
#     <thead>
#       <tr>
#         <th>Order date</th>
#         <th>Region</th>
#         <th>Item</th>
#         <th>Units</th>
#         <th>Unit cost</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>1/6/2018</td>
#         <td>East</td>
#         <td>Pencil</td>
#         <td>95</td>
#         <td>1.99</td>
#       </tr>
#       <tr>
#         <td>1/23/2018</td>
#         <td>Central</td>
#         <td>Binder</td>
#         <td>50</td>
#         <td>19.99</td>
#       </tr>
#       <tr>
#         <td>2/9/2018</td>
#         <td>Central</td>
#         <td>Pencil</td>
#         <td>36</td>
#         <td>4.99</td>
#       </tr>
#       <tr>
#         <td>3/15/2018</td>
#         <td>West</td>
#         <td>Pen</td>
#         <td>27</td>
#         <td>19.99</td>
#       </tr>
#     </tbody>
# </table>

# %%
dfs = pd.read_html(html_string)

# %%
dfs
# Out:
# [  Order date   Region    Item  Units  Unit cost
#  0   1/6/2018     East  Pencil     95       1.99
#  1  1/23/2018  Central  Binder     50      19.99
#  2   2/9/2018  Central  Pencil     36       4.99
#  3  3/15/2018     West     Pen     27      19.99]

# %%
len(dfs)
# Out:
# 1

# %%
df = dfs[0]

# %%
df
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %%
df.loc[df['Region'] == 'Central']
# Out:
#   Order date   Region    Item  Units  Unit cost
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99

# %%
df.loc[df['Units'] >= 50]
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99

# %% [markdown]
# ## Defining the header

# %%
html_string = """
<table>
  <tr>
    <td>Order date</td>
    <td>Region</td> 
    <td>Item</td>
    <td>Units</td>
    <td>Unit cost</td>
  </tr>
  <tr>
    <td>1/6/2018</td>
    <td>East</td> 
    <td>Pencil</td>
    <td>95</td>
    <td>1.99</td>
  </tr>
  <tr>
    <td>1/23/2018</td>
    <td>Central</td> 
    <td>Binder</td>
    <td>50</td>
    <td>19.99</td>
  </tr>
  <tr>
    <td>2/9/2018</td>
    <td>Central</td> 
    <td>Pencil</td>
    <td>36</td>
    <td>4.99</td>
  </tr>
  <tr>
    <td>3/15/2018</td>
    <td>West</td> 
    <td>Pen</td>
    <td>27</td>
    <td>19.99</td>
  </tr>
</table>
"""

# %%
display(HTML(html_string))
# Out:
# <table>
#   <tr>
#     <td>Order date</td>
#     <td>Region</td>
#     <td>Item</td>
#     <td>Units</td>
#     <td>Unit cost</td>
#   </tr>
#   <tr>
#     <td>1/6/2018</td>
#     <td>East</td>
#     <td>Pencil</td>
#     <td>95</td>
#     <td>1.99</td>
#   </tr>
#   <tr>
#     <td>1/23/2018</td>
#     <td>Central</td>
#     <td>Binder</td>
#     <td>50</td>
#     <td>19.99</td>
#   </tr>
#   <tr>
#     <td>2/9/2018</td>
#     <td>Central</td>
#     <td>Pencil</td>
#     <td>36</td>
#     <td>4.99</td>
#   </tr>
#   <tr>
#     <td>3/15/2018</td>
#     <td>West</td>
#     <td>Pen</td>
#     <td>27</td>
#     <td>19.99</td>
#   </tr>
# </table>

# %%
dfs = pd.read_html(html_string, header=[0])

# %%
dfs
# Out:
# [  Order date   Region    Item  Units  Unit cost
#  0   1/6/2018     East  Pencil     95       1.99
#  1  1/23/2018  Central  Binder     50      19.99
#  2   2/9/2018  Central  Pencil     36       4.99
#  3  3/15/2018     West     Pen     27      19.99]

# %%
df = dfs[0]

# %%
df
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %% [markdown]
# ## Parsing HTML tables from the web

# %% [markdown]
# ### Simple example

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2019_per_game.html"

# %%
nba_tables = pd.read_html(html_url)

# %%
len(nba_tables)
# Out:
# 1

# %%
nba = nba_tables[0]

# %%
nba
# Out:
#       Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0      1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2
# 1      2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3
# 2      3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3
# 3      4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9
# 4      5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0
# ..   ...           ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...  ...
# 729  528  Tyler Zeller   C  29  MEM   4   1  20.5  4.0   7.0  ...  .778  2.3
# 730  529    Ante Žižić   C  22  CLE  59  25  18.3  3.1   5.6  ...  .705  1.8
# 731  530   Ivica Zubac   C  21  TOT  59  37  17.6  3.6   6.4  ...  .802  1.9
# 732  530   Ivica Zubac   C  21  LAL  33  12  15.6  3.4   5.8  ...  .864  1.6
# 733  530   Ivica Zubac   C  21  LAC  26  25  20.2  3.8   7.2  ...  .733  2.3
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0    1.4  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1    2.2  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2    1.4  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3    4.6  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4    5.3  7.3  2.2  0.9  0.8  1.5  2.5   8.9
# ..   ...  ...  ...  ...  ...  ...  ...   ...
# 729  2.3  4.5  0.8  0.3  0.8  1.0  4.0  11.5
# 730  3.6  5.4  0.9  0.2  0.4  1.0  1.9   7.8
# 731  4.2  6.1  1.1  0.2  0.9  1.2  2.3   8.9
# 732  3.3  4.9  0.8  0.1  0.8  1.0  2.2   8.5
# 733  5.3  7.7  1.5  0.4  0.9  1.4  2.5   9.4
#
# [734 rows x 30 columns]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      734 non-null    object
#  1   Player  734 non-null    object
#  2   Pos     734 non-null    object
#  3   Age     734 non-null    object
#  4   Tm      734 non-null    object
#  5   G       734 non-null    object
#  6   GS      734 non-null    object
#  7   MP      734 non-null    object
#  8   FG      734 non-null    object
#  9   FGA     734 non-null    object
#  10  FG%     728 non-null    object
#  11  3P      734 non-null    object
#  12  3PA     734 non-null    object
#  13  3P%     687 non-null    object
#  14  2P      734 non-null    object
#  15  2PA     734 non-null    object
#  16  2P%     719 non-null    object
#  17  eFG%    728 non-null    object
#  18  FT      734 non-null    object
#  19  FTA     734 non-null    object
#  20  FT%     691 non-null    object
#  21  ORB     734 non-null    object
#  22  DRB     734 non-null    object
#  23  TRB     734 non-null    object
#  24  AST     734 non-null    object
#  25  STL     734 non-null    object
#  26  BLK     734 non-null    object
#  27  TOV     734 non-null    object
#  28  PF      734 non-null    object
#  29  PTS     734 non-null    object
# dtypes: object(30)
# memory usage: 172.2+ KB

# %%
nba.describe()
# Out:
#          Rk  Player  Pos  Age   Tm    G   GS   MP   FG  FGA  ...  FT%  ORB  \
# count   734     734  734  734  734  734  734  734  734  734  ...  691  734
# unique  531     531   11   23   32   83   81  291   96  172  ...  273   44
# top      Rk  Player   SG   23  TOT    G    0   MP   FG  FGA  ...  FT%  0.3
# freq     26      26  174   75   86   26  199   26   26   26  ...   26   81
#
#         DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# count   734  734  734  734  734  734  734  734
# unique   90  111   75   26   26   40   41  200
# top     1.8  TRB  0.8  0.3  0.1  0.8  1.7  PTS
# freq     26   26   40   93  121   59   46   26
#
# [4 rows x 30 columns]

# %%
nba.isnull().count()
# Out:
# Rk        734
# Player    734
# Pos       734
# Age       734
# Tm        734
# G         734
# GS        734
# MP        734
# FG        734
# FGA       734
# FG%       734
# 3P        734
# 3PA       734
# 3P%       734
# 2P        734
# 2PA       734
# 2P%       734
# eFG%      734
# FT        734
# FTA       734
# FT%       734
# ORB       734
# DRB       734
# TRB       734
# AST       734
# STL       734
# BLK       734
# TOV       734
# PF        734
# PTS       734
# dtype: int64

# %%
nba.head(30)
# Out:
#     Rk                  Player  Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0    1            Álex Abrines   SG   25  OKC  31   2  19.0   1.8   5.1  ...
# 1    2              Quincy Acy   PF   28  PHO  10   0  12.3   0.4   1.8  ...
# 2    3            Jaylen Adams   PG   22  ATL  34   1  12.6   1.1   3.2  ...
# 3    4            Steven Adams    C   25  OKC  80  80  33.4   6.0  10.1  ...
# 4    5             Bam Adebayo    C   21  MIA  82  28  23.3   3.4   5.9  ...
# 5    6               Deng Adel   SF   21  CLE  19   3  10.2   0.6   1.9  ...
# 6    7  DeVaughn Akoon-Purcell   SG   25  DEN   7   0   3.1   0.4   1.4  ...
# 7    8       LaMarcus Aldridge    C   33  SAS  81  81  33.2   8.4  16.3  ...
# 8    9            Rawle Alkins   SG   21  CHI  10   1  12.0   1.3   3.9  ...
# 9   10           Grayson Allen   SG   23  UTA  38   2  10.9   1.8   4.7  ...
# 10  11           Jarrett Allen    C   20  BRK  80  80  26.2   4.2   7.1  ...
# 11  12            Kadeem Allen   PG   26  NYK  19   1  21.9   3.4   7.4  ...
# 12  13         Al-Farouq Aminu   PF   28  POR  81  81  28.3   3.2   7.3  ...
# 13  14         Justin Anderson   SF   25  ATL  48   4   9.6   1.3   3.3  ...
# 14  15           Kyle Anderson   SF   25  MEM  43  40  29.8   3.5   6.4  ...
# 15  16           Ryan Anderson   PF   30  TOT  25   8  12.9   0.8   2.8  ...
# 16  16           Ryan Anderson   PF   30  PHO  15   8  18.5   1.3   4.0  ...
# 17  16           Ryan Anderson   PF   30  MIA  10   0   4.4   0.2   0.9  ...
# 18  17            Ike Anigbogu    C   20  IND   3   0   2.0   0.0   1.0  ...
# 19  18   Giannis Antetokounmpo   PF   24  MIL  72  72  32.8  10.0  17.3  ...
# 20  19    Kostas Antetokounmpo   PF   21  DAL   2   0   5.5   0.0   1.5  ...
# 21  20         Carmelo Anthony   PF   34  HOU  10   2  29.4   4.9  12.1  ...
# 22  Rk                  Player  Pos  Age   Tm   G  GS    MP    FG   FGA  ...
# 23  21              OG Anunoby   SF   21  TOR  67   6  20.2   2.7   6.0  ...
# 24  22        Ryan Arcidiacono   PG   24  CHI  81  32  24.2   2.3   5.2  ...
# 25  23            Trevor Ariza   SF   33  TOT  69  69  34.0   4.3  10.7  ...
# 26  23            Trevor Ariza   SF   33  PHO  26  26  34.0   3.3   8.7  ...
# 27  23            Trevor Ariza   SF   33  WAS  43  43  34.1   4.8  11.8  ...
# 28  24           D.J. Augustin   PG   31  ORL  81  81  28.0   3.9   8.4  ...
# 29  25           Deandre Ayton    C   20  PHO  71  70  30.7   7.2  12.3  ...
#
#       FT%  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0    .923  0.2   1.4   1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1    .700  0.3   2.2   2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2    .778  0.3   1.4   1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3    .500  4.9   4.6   9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4    .735  2.0   5.3   7.3  2.2  0.9  0.8  1.5  2.5   8.9
# 5   1.000  0.2   0.8   1.0  0.3  0.1  0.2  0.3  0.7   1.7
# 6    .500  0.1   0.4   0.6  0.9  0.3  0.0  0.3  0.6   1.0
# 7    .847  3.1   6.1   9.2  2.4  0.5  1.3  1.8  2.2  21.3
# 8    .667  1.1   1.5   2.6  1.3  0.1  0.0  0.8  0.7   3.7
# 9    .750  0.1   0.5   0.6  0.7  0.2  0.2  0.9  1.2   5.6
# 10   .709  2.4   6.0   8.4  1.4  0.5  1.5  1.3  2.3  10.9
# 11   .778  0.4   2.3   2.7  4.0  0.8  0.2  1.4  2.4   9.9
# 12   .867  1.4   6.1   7.5  1.3  0.8  0.4  0.9  1.8   9.4
# 13   .743  0.5   1.3   1.8  0.5  0.5  0.3  0.5  1.0   3.7
# 14   .578  1.1   4.7   5.8  3.0  1.3  0.9  1.3  2.6   8.0
# 15   .750  0.7   1.4   2.2  0.8  0.2  0.0  0.6  1.0   2.5
# 16   .786  0.9   2.1   3.0  1.1  0.2  0.1  0.8  1.5   3.7
# 17   .500  0.4   0.5   0.9  0.2  0.1  0.0  0.2  0.2   0.7
# 18    NaN  0.3   0.7   1.0  0.3  0.0  0.3  0.3  0.0   0.0
# 19   .729  2.2  10.3  12.5  5.9  1.3  1.5  3.7  3.2  27.7
# 20   .500  0.0   0.5   0.5  0.0  1.0  0.0  0.5  0.0   1.0
# 21   .682  0.9   4.5   5.4  0.5  0.4  0.7  0.8  3.2  13.4
# 22    FT%  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 23   .581  0.9   2.1   2.9  0.7  0.7  0.3  0.8  2.1   7.0
# 24   .873  0.3   2.4   2.7  3.3  0.8  0.0  0.8  2.1   6.7
# 25   .793  0.7   4.7   5.4  3.7  1.3  0.3  1.5  1.9  12.5
# 26   .837  0.6   5.0   5.6  3.3  1.5  0.3  1.5  1.7   9.9
# 27   .777  0.8   4.5   5.3  3.8  1.2  0.3  1.6  2.0  14.1
# 28   .866  0.5   2.0   2.5  5.3  0.6  0.0  1.6  1.4  11.7
# 29   .746  3.1   7.1  10.3  1.8  0.9  0.9  1.8  2.9  16.3
#
# [30 rows x 30 columns]

# %%
nba.drop(range(22, df.shape[0] + 1, 20))
# Out:
#       Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0      1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2
# 1      2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3
# 2      3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3
# 3      4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9
# 4      5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0
# ..   ...           ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...  ...
# 729  528  Tyler Zeller   C  29  MEM   4   1  20.5  4.0   7.0  ...  .778  2.3
# 730  529    Ante Žižić   C  22  CLE  59  25  18.3  3.1   5.6  ...  .705  1.8
# 731  530   Ivica Zubac   C  21  TOT  59  37  17.6  3.6   6.4  ...  .802  1.9
# 732  530   Ivica Zubac   C  21  LAL  33  12  15.6  3.4   5.8  ...  .864  1.6
# 733  530   Ivica Zubac   C  21  LAC  26  25  20.2  3.8   7.2  ...  .733  2.3
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0    1.4  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1    2.2  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2    1.4  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3    4.6  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4    5.3  7.3  2.2  0.9  0.8  1.5  2.5   8.9
# ..   ...  ...  ...  ...  ...  ...  ...   ...
# 729  2.3  4.5  0.8  0.3  0.8  1.0  4.0  11.5
# 730  3.6  5.4  0.9  0.2  0.4  1.0  1.9   7.8
# 731  4.2  6.1  1.1  0.2  0.9  1.2  2.3   8.9
# 732  3.3  4.9  0.8  0.1  0.8  1.0  2.2   8.5
# 733  5.3  7.7  1.5  0.4  0.9  1.4  2.5   9.4
#
# [734 rows x 30 columns]

# %%
nba.iloc[22]
# Out:
# Rk            Rk
# Player    Player
# Pos          Pos
# Age          Age
# Tm            Tm
# G              G
# GS            GS
# MP            MP
# FG            FG
# FGA          FGA
# FG%          FG%
# 3P            3P
# 3PA          3PA
# 3P%          3P%
# 2P            2P
# 2PA          2PA
# 2P%          2P%
# eFG%        eFG%
# FT            FT
# FTA          FTA
# FT%          FT%
# ORB          ORB
# DRB          DRB
# TRB          TRB
# AST          AST
# STL          STL
# BLK          BLK
# TOV          TOV
# PF            PF
# PTS          PTS
# Name: 22, dtype: object

# %%
nba.drop_duplicates(subset=['Rk'], inplace=True)

# %%
nba.head(50)
# Out:
#     Rk                  Player    Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0    1            Álex Abrines     SG   25  OKC  31   2  19.0   1.8   5.1
# 1    2              Quincy Acy     PF   28  PHO  10   0  12.3   0.4   1.8
# 2    3            Jaylen Adams     PG   22  ATL  34   1  12.6   1.1   3.2
# 3    4            Steven Adams      C   25  OKC  80  80  33.4   6.0  10.1
# 4    5             Bam Adebayo      C   21  MIA  82  28  23.3   3.4   5.9
# 5    6               Deng Adel     SF   21  CLE  19   3  10.2   0.6   1.9
# 6    7  DeVaughn Akoon-Purcell     SG   25  DEN   7   0   3.1   0.4   1.4
# 7    8       LaMarcus Aldridge      C   33  SAS  81  81  33.2   8.4  16.3
# 8    9            Rawle Alkins     SG   21  CHI  10   1  12.0   1.3   3.9
# 9   10           Grayson Allen     SG   23  UTA  38   2  10.9   1.8   4.7
# 10  11           Jarrett Allen      C   20  BRK  80  80  26.2   4.2   7.1
# 11  12            Kadeem Allen     PG   26  NYK  19   1  21.9   3.4   7.4
# 12  13         Al-Farouq Aminu     PF   28  POR  81  81  28.3   3.2   7.3
# 13  14         Justin Anderson     SF   25  ATL  48   4   9.6   1.3   3.3
# 14  15           Kyle Anderson     SF   25  MEM  43  40  29.8   3.5   6.4
# 15  16           Ryan Anderson     PF   30  TOT  25   8  12.9   0.8   2.8
# 18  17            Ike Anigbogu      C   20  IND   3   0   2.0   0.0   1.0
# 19  18   Giannis Antetokounmpo     PF   24  MIL  72  72  32.8  10.0  17.3
# 20  19    Kostas Antetokounmpo     PF   21  DAL   2   0   5.5   0.0   1.5
# 21  20         Carmelo Anthony     PF   34  HOU  10   2  29.4   4.9  12.1
# 22  Rk                  Player    Pos  Age   Tm   G  GS    MP    FG   FGA
# 23  21              OG Anunoby     SF   21  TOR  67   6  20.2   2.7   6.0
# 24  22        Ryan Arcidiacono     PG   24  CHI  81  32  24.2   2.3   5.2
# 25  23            Trevor Ariza     SF   33  TOT  69  69  34.0   4.3  10.7
# 28  24           D.J. Augustin     PG   31  ORL  81  81  28.0   3.9   8.4
# 29  25           Deandre Ayton      C   20  PHO  71  70  30.7   7.2  12.3
# 30  26            Dwayne Bacon     SG   23  CHO  43  13  17.7   2.8   6.0
# 31  27       Marvin Bagley III     PF   19  SAC  62   4  25.3   5.7  11.4
# 32  28               Ron Baker     SG   25  TOT  15   0  10.1   0.3   1.3
# 35  29            Wade Baldwin     PG   22  POR  16   0   5.9   0.6   2.1
# 36  30              Lonzo Ball     PG   21  LAL  47  45  30.3   3.9   9.7
# 37  31                Mo Bamba      C   20  ORL  47   1  16.3   2.5   5.2
# 38  32              J.J. Barea     PG   34  DAL  38   0  19.8   4.2  10.1
# 39  33         Harrison Barnes  PF-SF   26  TOT  77  77  32.9   5.6  13.3
# 42  34             Will Barton     SF   28  DEN  43  38  27.7   4.3  10.7
# 43  35        Keita Bates-Diop     SF   23  MIN  30   3  16.8   2.0   4.7
# 44  36           Nicolas Batum     SF   30  CHO  75  72  31.4   3.4   7.5
# 45  37          Jerryd Bayless     PG   30  MIN  34   6  19.3   2.4   6.8
# 46  38             Aron Baynes      C   32  BOS  51  18  16.1   2.1   4.4
# 47  39           Kent Bazemore     SG   29  ATL  67  35  24.5   4.1  10.3
# 48  40            Bradley Beal     SG   25  WAS  82  82  36.9   9.3  19.6
# 50  41           Malik Beasley     SG   22  DEN  81  18  23.2   4.3   9.1
# 51  42         Michael Beasley     PF   30  LAL  26   2  10.7   2.9   5.9
# 52  43         Marco Belinelli     SG   32  SAS  79   1  23.0   3.6   8.7
# 53  44             Jordan Bell      C   24  GSW  68   3  11.6   1.5   2.8
# 54  45         DeAndre' Bembry     SG   24  ATL  82  15  23.5   3.4   7.5
# 55  46           Dragan Bender     PF   21  PHO  46  27  18.0   1.9   4.3
# 56  47          Dairis Bertāns     SG   29  NOP  12   0  13.9   1.0   3.9
# 57  48           Dāvis Bertāns     PF   26  SAS  76  12  21.5   2.7   6.0
# 58  49        Patrick Beverley     PG   30  LAC  78  49  27.4   2.5   6.1
#
#     ...    FT%  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   ...   .923  0.2   1.4   1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1   ...   .700  0.3   2.2   2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2   ...   .778  0.3   1.4   1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3   ...   .500  4.9   4.6   9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4   ...   .735  2.0   5.3   7.3  2.2  0.9  0.8  1.5  2.5   8.9
# 5   ...  1.000  0.2   0.8   1.0  0.3  0.1  0.2  0.3  0.7   1.7
# 6   ...   .500  0.1   0.4   0.6  0.9  0.3  0.0  0.3  0.6   1.0
# 7   ...   .847  3.1   6.1   9.2  2.4  0.5  1.3  1.8  2.2  21.3
# 8   ...   .667  1.1   1.5   2.6  1.3  0.1  0.0  0.8  0.7   3.7
# 9   ...   .750  0.1   0.5   0.6  0.7  0.2  0.2  0.9  1.2   5.6
# 10  ...   .709  2.4   6.0   8.4  1.4  0.5  1.5  1.3  2.3  10.9
# 11  ...   .778  0.4   2.3   2.7  4.0  0.8  0.2  1.4  2.4   9.9
# 12  ...   .867  1.4   6.1   7.5  1.3  0.8  0.4  0.9  1.8   9.4
# 13  ...   .743  0.5   1.3   1.8  0.5  0.5  0.3  0.5  1.0   3.7
# 14  ...   .578  1.1   4.7   5.8  3.0  1.3  0.9  1.3  2.6   8.0
# 15  ...   .750  0.7   1.4   2.2  0.8  0.2  0.0  0.6  1.0   2.5
# 18  ...    NaN  0.3   0.7   1.0  0.3  0.0  0.3  0.3  0.0   0.0
# 19  ...   .729  2.2  10.3  12.5  5.9  1.3  1.5  3.7  3.2  27.7
# 20  ...   .500  0.0   0.5   0.5  0.0  1.0  0.0  0.5  0.0   1.0
# 21  ...   .682  0.9   4.5   5.4  0.5  0.4  0.7  0.8  3.2  13.4
# 22  ...    FT%  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 23  ...   .581  0.9   2.1   2.9  0.7  0.7  0.3  0.8  2.1   7.0
# 24  ...   .873  0.3   2.4   2.7  3.3  0.8  0.0  0.8  2.1   6.7
# 25  ...   .793  0.7   4.7   5.4  3.7  1.3  0.3  1.5  1.9  12.5
# 28  ...   .866  0.5   2.0   2.5  5.3  0.6  0.0  1.6  1.4  11.7
# 29  ...   .746  3.1   7.1  10.3  1.8  0.9  0.9  1.8  2.9  16.3
# 30  ...   .739  0.2   1.9   2.1  1.1  0.3  0.1  0.4  1.7   7.3
# 31  ...   .691  2.6   5.0   7.6  1.0  0.5  1.0  1.6  1.9  14.9
# 32  ...   .833  0.1   0.7   0.7  1.0  0.4  0.1  0.3  1.2   0.9
# 35  ...   .727  0.1   0.8   0.9  0.8  0.1  0.1  0.9  0.7   1.9
# 36  ...   .417  1.1   4.2   5.3  5.4  1.5  0.4  2.2  2.4   9.9
# 37  ...   .587  1.4   3.6   5.0  0.8  0.3  1.4  0.9  2.2   6.2
# 38  ...   .705  0.3   2.2   2.5  5.6  0.6  0.0  1.9  1.3  10.9
# 39  ...   .824  0.7   3.9   4.7  1.5  0.6  0.2  1.3  1.6  16.4
# 42  ...   .770  0.7   3.9   4.6  2.9  0.4  0.5  1.5  1.9  11.5
# 43  ...   .643  0.5   2.2   2.8  0.6  0.6  0.5  0.5  1.0   5.0
# 44  ...   .865  0.9   4.3   5.2  3.3  0.9  0.6  1.6  1.9   9.3
# 45  ...   .571  0.3   1.5   1.8  3.5  0.5  0.1  0.9  1.6   6.1
# 46  ...   .855  1.7   3.0   4.7  1.1  0.2  0.7  0.8  2.5   5.6
# 47  ...   .726  0.6   3.3   3.9  2.3  1.3  0.6  1.8  2.5  11.6
# 48  ...   .808  1.1   3.9   5.0  5.5  1.5  0.7  2.7  2.8  25.6
# 50  ...   .848  0.4   2.0   2.5  1.2  0.7  0.1  0.7  1.4  11.3
# 51  ...   .718  0.5   1.8   2.3  1.0  0.3  0.4  1.0  1.6   7.0
# 52  ...   .903  0.2   2.3   2.5  1.7  0.4  0.1  0.9  1.5  10.5
# 53  ...   .610  0.8   1.9   2.7  1.1  0.3  0.8  0.6  1.2   3.3
# 54  ...   .640  0.7   3.7   4.4  2.5  1.3  0.5  1.7  2.3   8.4
# 55  ...   .593  0.7   3.2   4.0  1.2  0.4  0.5  0.8  2.0   5.0
# 56  ...    NaN  0.2   0.6   0.8  0.8  0.1  0.0  0.2  0.6   2.8
# 57  ...   .883  0.3   3.2   3.5  1.3  0.5  0.4  0.6  1.8   8.0
# 58  ...   .780  1.0   4.0   5.0  3.8  0.9  0.6  1.1  3.4   7.6
#
# [50 rows x 30 columns]

# %%
nba.drop([22], inplace=True)

# %%
nba.head(25)
# Out:
#     Rk                  Player Pos Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0    1            Álex Abrines  SG  25  OKC  31   2  19.0   1.8   5.1  ...
# 1    2              Quincy Acy  PF  28  PHO  10   0  12.3   0.4   1.8  ...
# 2    3            Jaylen Adams  PG  22  ATL  34   1  12.6   1.1   3.2  ...
# 3    4            Steven Adams   C  25  OKC  80  80  33.4   6.0  10.1  ...
# 4    5             Bam Adebayo   C  21  MIA  82  28  23.3   3.4   5.9  ...
# 5    6               Deng Adel  SF  21  CLE  19   3  10.2   0.6   1.9  ...
# 6    7  DeVaughn Akoon-Purcell  SG  25  DEN   7   0   3.1   0.4   1.4  ...
# 7    8       LaMarcus Aldridge   C  33  SAS  81  81  33.2   8.4  16.3  ...
# 8    9            Rawle Alkins  SG  21  CHI  10   1  12.0   1.3   3.9  ...
# 9   10           Grayson Allen  SG  23  UTA  38   2  10.9   1.8   4.7  ...
# 10  11           Jarrett Allen   C  20  BRK  80  80  26.2   4.2   7.1  ...
# 11  12            Kadeem Allen  PG  26  NYK  19   1  21.9   3.4   7.4  ...
# 12  13         Al-Farouq Aminu  PF  28  POR  81  81  28.3   3.2   7.3  ...
# 13  14         Justin Anderson  SF  25  ATL  48   4   9.6   1.3   3.3  ...
# 14  15           Kyle Anderson  SF  25  MEM  43  40  29.8   3.5   6.4  ...
# 15  16           Ryan Anderson  PF  30  TOT  25   8  12.9   0.8   2.8  ...
# 18  17            Ike Anigbogu   C  20  IND   3   0   2.0   0.0   1.0  ...
# 19  18   Giannis Antetokounmpo  PF  24  MIL  72  72  32.8  10.0  17.3  ...
# 20  19    Kostas Antetokounmpo  PF  21  DAL   2   0   5.5   0.0   1.5  ...
# 21  20         Carmelo Anthony  PF  34  HOU  10   2  29.4   4.9  12.1  ...
# 23  21              OG Anunoby  SF  21  TOR  67   6  20.2   2.7   6.0  ...
# 24  22        Ryan Arcidiacono  PG  24  CHI  81  32  24.2   2.3   5.2  ...
# 25  23            Trevor Ariza  SF  33  TOT  69  69  34.0   4.3  10.7  ...
# 28  24           D.J. Augustin  PG  31  ORL  81  81  28.0   3.9   8.4  ...
# 29  25           Deandre Ayton   C  20  PHO  71  70  30.7   7.2  12.3  ...
#
#       FT%  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0    .923  0.2   1.4   1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1    .700  0.3   2.2   2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2    .778  0.3   1.4   1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3    .500  4.9   4.6   9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4    .735  2.0   5.3   7.3  2.2  0.9  0.8  1.5  2.5   8.9
# 5   1.000  0.2   0.8   1.0  0.3  0.1  0.2  0.3  0.7   1.7
# 6    .500  0.1   0.4   0.6  0.9  0.3  0.0  0.3  0.6   1.0
# 7    .847  3.1   6.1   9.2  2.4  0.5  1.3  1.8  2.2  21.3
# 8    .667  1.1   1.5   2.6  1.3  0.1  0.0  0.8  0.7   3.7
# 9    .750  0.1   0.5   0.6  0.7  0.2  0.2  0.9  1.2   5.6
# 10   .709  2.4   6.0   8.4  1.4  0.5  1.5  1.3  2.3  10.9
# 11   .778  0.4   2.3   2.7  4.0  0.8  0.2  1.4  2.4   9.9
# 12   .867  1.4   6.1   7.5  1.3  0.8  0.4  0.9  1.8   9.4
# 13   .743  0.5   1.3   1.8  0.5  0.5  0.3  0.5  1.0   3.7
# 14   .578  1.1   4.7   5.8  3.0  1.3  0.9  1.3  2.6   8.0
# 15   .750  0.7   1.4   2.2  0.8  0.2  0.0  0.6  1.0   2.5
# 18    NaN  0.3   0.7   1.0  0.3  0.0  0.3  0.3  0.0   0.0
# 19   .729  2.2  10.3  12.5  5.9  1.3  1.5  3.7  3.2  27.7
# 20   .500  0.0   0.5   0.5  0.0  1.0  0.0  0.5  0.0   1.0
# 21   .682  0.9   4.5   5.4  0.5  0.4  0.7  0.8  3.2  13.4
# 23   .581  0.9   2.1   2.9  0.7  0.7  0.3  0.8  2.1   7.0
# 24   .873  0.3   2.4   2.7  3.3  0.8  0.0  0.8  2.1   6.7
# 25   .793  0.7   4.7   5.4  3.7  1.3  0.3  1.5  1.9  12.5
# 28   .866  0.5   2.0   2.5  5.3  0.6  0.0  1.6  1.4  11.7
# 29   .746  3.1   7.1  10.3  1.8  0.9  0.9  1.8  2.9  16.3
#
# [25 rows x 30 columns]

# %% [markdown]
# ### Complex sample

# %%
import requests

html_url = "https://en.wikipedia.org/wiki/The_Simpsons"

# %%
r = requests.get(html_url)

wiki_tables = pd.read_html(r.text, header=0)

# %%
len(wiki_tables)
# Out:
# 31

# %%
simpsons = wiki_tables[1]

# %%
simpsons.head()
# Out:
#    Season Season.1  No. ofepisodes    Originally aired Originally aired.1  \
# 0  Season   Season  No. ofepisodes     Season premiere      Season finale
# 1  Season   Season  No. ofepisodes     Season premiere      Season finale
# 2       1  1989–90              13   December 17, 1989       May 13, 1990
# 3       2  1990–91              22    October 11, 1990      July 11, 1991
# 4       3  1991–92              24  September 19, 1991    August 27, 1992
#
#   Originally aired.2                 Viewership          Viewership.1  \
# 0     Time slot (ET)  Avg. viewers(in millions)  Most watched episode
# 1     Time slot (ET)  Avg. viewers(in millions)     Viewers(millions)
# 2     Sunday 8:30 pm                       27.8                  33.5
# 3   Thursday 8:00 pm                       24.4                  33.6
# 4   Thursday 8:00 pm                       21.8                  25.5
#
#               Viewership.2
# 0     Most watched episode
# 1            Episode title
# 2  "Life on the Fast Lane"
# 3       "Bart Gets an 'F'"
# 4          "Colonel Homer"

# %%
simpsons.drop([0,1], inplace=True)
simpsons.head()
# Out:
#   Season Season.1 No. ofepisodes    Originally aired Originally aired.1  \
# 2      1  1989–90             13   December 17, 1989       May 13, 1990
# 3      2  1990–91             22    October 11, 1990      July 11, 1991
# 4      3  1991–92             24  September 19, 1991    August 27, 1992
# 5      4  1992–93             22  September 24, 1992       May 13, 1993
# 6      5  1993–94             22  September 30, 1993       May 19, 1994
#
#   Originally aired.2 Viewership Viewership.1              Viewership.2
# 2     Sunday 8:30 pm       27.8         33.5   "Life on the Fast Lane"
# 3   Thursday 8:00 pm       24.4         33.6        "Bart Gets an 'F'"
# 4   Thursday 8:00 pm       21.8         25.5           "Colonel Homer"
# 5   Thursday 8:00 pm       22.4         28.6       "Lisa's First Word"
# 6   Thursday 8:00 pm       18.9         24.0  "Treehouse of Horror IV"

# %%
simpsons.set_index('Season', inplace=True)

# %%
simpsons['No. ofepisodes'].unique()
# Out:
# array(['13', '22', '24', '25', '23', '21', '20'], dtype=object)

# %%
simpsons['No. ofepisodes']
# Out:
# Season
# 1     13
# 2     22
# 3     24
# 4     22
# 5     22
# 6     25
# 7     25
# 8     25
# 9     25
# 10    23
# 11    22
# 12    21
# 13    22
# 14    22
# 15    22
# 16    21
# 17    22
# 18    22
# 19    20
# 20    21
# 21    23
# 22    22
# 23    22
# 24    22
# 25    22
# 26    22
# 27    22
# 28    22
# 29    21
# 30    23
# 31    22
# 32    22
# 33    22
# Name: No. ofepisodes, dtype: object

# %%
simpsons = simpsons.loc(simpsons['No. ofepisodes'] != 'TBA')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-b3da92b4c459> in <module>
# ----> 1 simpsons = simpsons.loc(simpsons['No. ofepisodes'] != 'TBA')
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     605
#     606         if axis is not None:
# --> 607             axis = self.obj._get_axis_number(axis)
#     608         new_self.axis = axis
#     609         return new_self
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     458     def _get_axis_number(cls, axis: Axis) -> int:
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#     462             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1784     def __hash__(self) -> int:
#    1785         raise TypeError(
# -> 1786             f"{repr(type(self).__name__)} objects are mutable, "
#    1787             f"thus they cannot be hashed"
#    1788         )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
min_episodes = simpsons['No. ofepisodes'].min()

min_episodes
# Out:
# '13'

# %%
si = simpsons['No. ofepisodes'] == min_episodes

simpsons[si]
# Out:
#        Season.1 No. ofepisodes   Originally aired Originally aired.1  \
# Season
# 1       1989–90             13  December 17, 1989       May 13, 1990
#
#        Originally aired.2 Viewership Viewership.1             Viewership.2
# Season
# 1          Sunday 8:30 pm       27.8         33.5  "Life on the Fast Lane"
